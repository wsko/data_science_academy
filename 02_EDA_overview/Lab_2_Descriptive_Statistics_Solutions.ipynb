# %% [markdown]
# ## Lab 2. Descriptive Statistics - solutions

# %% [markdown]
# In this lab we will explore the Finance Dataset from Kaggle using univariate and multivariate descriptive statistics:
# https://www.kaggle.com/datasets/nitindatta/finance-data

# %% [markdown]
# ### Part 1 Data Import and Inspection

# %% [markdown]
# ##### 1.1
#
# - Examine the Finance Dataset data file and the data dictionary using your favourite spreadsheet software (e.g., Excel)
# - Import Python libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ##### 1.2
# - Import the Finance Dataset as a Pandas data frame named _data_. Make sure that the source file "Finance_data.csv" is in your working directory
# - Examine the first few rows. What are the columns and what data types do they contain?

# %%
data = pd.read_csv("https://github.com/wsko/data_science_academy/raw/main/data/Finance_data.csv")
data.head().T
# Out:
#                                                           0  \
# gender                                               Female
# age                                                      34
# Investment_Avenues                                      Yes
# Mutual_Funds                                              1
# Equity_Market                                             2
# Debentures                                                5
# Government_Bonds                                          3
# Fixed_Deposits                                            7
# PPF                                                       6
# Gold                                                      4
# Stock_Market                                            Yes
# Factor                                              Returns
# Objective                              Capital Appreciation
# Purpose                                     Wealth Creation
# Duration                                          1-3 years
# Invest_Monitor                                      Monthly
# Expect                                              20%-30%
# Avenue                                          Mutual Fund
# What are your savings objectives?           Retirement Plan
# Reason_Equity                          Capital Appreciation
# Reason_Mutual                                Better Returns
# Reason_Bonds                                Safe Investment
# Reason_FD                                     Fixed Returns
# Source                             Newspapers and Magazines
#
#                                                        1  \
# gender                                            Female
# age                                                   23
# Investment_Avenues                                   Yes
# Mutual_Funds                                           4
# Equity_Market                                          3
# Debentures                                             2
# Government_Bonds                                       1
# Fixed_Deposits                                         5
# PPF                                                    6
# Gold                                                   7
# Stock_Market                                          No
# Factor                                    Locking Period
# Objective                           Capital Appreciation
# Purpose                                  Wealth Creation
# Duration                               More than 5 years
# Invest_Monitor                                    Weekly
# Expect                                           20%-30%
# Avenue                                       Mutual Fund
# What are your savings objectives?            Health Care
# Reason_Equity                                   Dividend
# Reason_Mutual                             Better Returns
# Reason_Bonds                             Safe Investment
# Reason_FD                            High Interest Rates
# Source                             Financial Consultants
#
#                                                       2                     3  \
# gender                                             Male                  Male
# age                                                  30                    22
# Investment_Avenues                                  Yes                   Yes
# Mutual_Funds                                          3                     2
# Equity_Market                                         6                     1
# Debentures                                            4                     3
# Government_Bonds                                      2                     7
# Fixed_Deposits                                        5                     6
# PPF                                                   1                     4
# Gold                                                  7                     5
# Stock_Market                                        Yes                   Yes
# Factor                                          Returns               Returns
# Objective                          Capital Appreciation                Income
# Purpose                                 Wealth Creation       Wealth Creation
# Duration                                      3-5 years      Less than 1 year
# Invest_Monitor                                    Daily                 Daily
# Expect                                          20%-30%               10%-20%
# Avenue                                           Equity                Equity
# What are your savings objectives?       Retirement Plan       Retirement Plan
# Reason_Equity                      Capital Appreciation              Dividend
# Reason_Mutual                              Tax Benefits  Fund Diversification
# Reason_Bonds                            Assured Returns        Tax Incentives
# Reason_FD                                 Fixed Returns   High Interest Rates
# Source                                       Television              Internet
#
#                                                       4
# gender                                           Female
# age                                                  24
# Investment_Avenues                                   No
# Mutual_Funds                                          2
# Equity_Market                                         1
# Debentures                                            3
# Government_Bonds                                      6
# Fixed_Deposits                                        4
# PPF                                                   5
# Gold                                                  7
# Stock_Market                                         No
# Factor                                          Returns
# Objective                                        Income
# Purpose                                 Wealth Creation
# Duration                               Less than 1 year
# Invest_Monitor                                    Daily
# Expect                                          20%-30%
# Avenue                                           Equity
# What are your savings objectives?       Retirement Plan
# Reason_Equity                      Capital Appreciation
# Reason_Mutual                            Better Returns
# Reason_Bonds                            Safe Investment
# Reason_FD                                     Risk Free
# Source                                         Internet

# %% [markdown]
# ##### 1.3
# How many rows and columns does the data frame _data_ have? What data types are in each pf the columns?

# %%
data.info()
## note that "object" typically stands for character strings
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Market                       40 non-null     object
#  11  Factor                             40 non-null     object
#  12  Objective                          40 non-null     object
#  13  Purpose                            40 non-null     object
#  14  Duration                           40 non-null     object
#  15  Invest_Monitor                     40 non-null     object
#  16  Expect                             40 non-null     object
#  17  Avenue                             40 non-null     object
#  18  What are your savings objectives?  40 non-null     object
#  19  Reason_Equity                      40 non-null     object
#  20  Reason_Mutual                      40 non-null     object
#  21  Reason_Bonds                       40 non-null     object
#  22  Reason_FD                          40 non-null     object
#  23  Source                             40 non-null     object
# dtypes: int64(8), object(16)
# memory usage: 7.6+ KB

# %% [markdown]
# ##### 1.4
# Print out all column names in the _data_ data frame

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Market', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %% [markdown]
# ##### 1.5
# Print and inspect the top 10 elements from the Columns "age", "Mutual_Funds", "Stock_Market" and "Source". We will talk more about data frame indexing in later sessions

# %%
data[["age", "Mutual_Funds", "Stock_Market", "Source"]][:10]
# Out:
#    age  Mutual_Funds Stock_Market                    Source
# 0   34             1          Yes  Newspapers and Magazines
# 1   23             4           No     Financial Consultants
# 2   30             3          Yes                Television
# 3   22             2          Yes                  Internet
# 4   24             2           No                  Internet
# 5   24             7           No                  Internet
# 6   27             3          Yes     Financial Consultants
# 7   21             2          Yes  Newspapers and Magazines
# 8   35             2          Yes                Television
# 9   31             1          Yes  Newspapers and Magazines

# %% [markdown]
# ##### 1.6
# Compute and print the number of distinct values (a.k.a. cardinality) for each column. Note that it could  a good idea to treat columns with cardinalities < 5 as categorical

# %%
data.nunique()
# Out:
# gender                                2
# age                                  14
# Investment_Avenues                    2
# Mutual_Funds                          6
# Equity_Market                         6
# Debentures                            7
# Government_Bonds                      7
# Fixed_Deposits                        7
# PPF                                   6
# Gold                                  6
# Stock_Market                          2
# Factor                                3
# Objective                             3
# Purpose                               3
# Duration                              4
# Invest_Monitor                        3
# Expect                                3
# Avenue                                4
# What are your savings objectives?     3
# Reason_Equity                         3
# Reason_Mutual                         3
# Reason_Bonds                          3
# Reason_FD                             3
# Source                                4
# dtype: int64

# %% [markdown]
# ### Part 2. Univariate Analysis

# %% [markdown]
# ##### 2.1
# Compute and inspect descriptive statstics for the numerical columns:
# - use a data frame method which computes and prints the minimum, maximum, mean, median and standard deviation
# - inspect the outputs and compare the mean and median for each column

# %%
data.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# 50%          3.500000   1.000000   6.000000
# 75%          5.000000   2.250000   7.000000
# max          7.000000   6.000000   7.000000

# %% [markdown]
# ##### 2.2
# How would you explain the significant discrepancy of the mean an median for the column "PPF"? Hint: use frequency tables or histograms. Which PPF value has the highest freqeuncy?

# %%
plt.hist(data['PPF'], bins = 6)
plt.show()
data['PPF'].value_counts()
# Out:
# 1    24
# 2     6
# 6     3
# 3     3
# 4     2
# 5     2
# Name: PPF, dtype: int64

# %% [markdown]
# ##### 2.3
# The describe() method is applied to numerical columns by default. Add an argument to describe the "object" columns. Find the Mode of the "Duration" column

# %%
data.describe(include='object').T
##Mode(duration) = "3-5 years"
# Out:
#                                   count unique                    top freq
# gender                               40      2                   Male   25
# Investment_Avenues                   40      2                    Yes   37
# Stock_Market                         40      2                    Yes   35
# Factor                               40      3                Returns   25
# Objective                            40      3   Capital Appreciation   26
# Purpose                              40      3        Wealth Creation   32
# Duration                             40      4              3-5 years   19
# Invest_Monitor                       40      3                Monthly   29
# Expect                               40      3                20%-30%   32
# Avenue                               40      4            Mutual Fund   18
# What are your savings objectives?    40      3        Retirement Plan   24
# Reason_Equity                        40      3   Capital Appreciation   30
# Reason_Mutual                        40      3         Better Returns   24
# Reason_Bonds                         40      3        Assured Returns   26
# Reason_FD                            40      3              Risk Free   19
# Source                               40      4  Financial Consultants   16

# %% [markdown]
# ##### 2.4
# Compute and inspect frequency tables for the categorical columns. Answer the following questions:
#
# 1. Is our data set gender biased? Which gender has more examples?
#
# 2. What is the least frequent value of the "Source" column?
#
# __Challenge:__ write a for loop to generate the frequensy tables for all object columns programmatically

# %%
## Frequency table for "gender":

data['gender'].value_counts()
# Out:
# Male      25
# Female    15
# Name: gender, dtype: int64

# %%
## Frequency table for "Source":

data['Source'].value_counts()
# Out:
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: Source, dtype: int64

# %%
## code reusability:e you can write a loop to compute a frequency table for each 'object' column

for column in data.describe(include='object').columns:  ##what are we iterating over?
    print(data[column].value_counts(), '\n', '\n')      ## column can be a variable! (no quotes)
# Out:
# Male      25
# Female    15
# Name: gender, dtype: int64
#
#
# Yes    37
# No      3
# Name: Investment_Avenues, dtype: int64
#
#
# Yes    35
# No      5
# Name: Stock_Market, dtype: int64
#
#
# Returns           25
# Risk              14
# Locking Period     1
# Name: Factor, dtype: int64
#
#
# Capital Appreciation    26
# Growth                  11
# Income                   3
# Name: Objective, dtype: int64
#
#
# Wealth Creation       32
# Savings for Future     6
# Returns                2
# Name: Purpose, dtype: int64
#
#
# 3-5 years            19
# 1-3 years            18
# Less than 1 year      2
# More than 5 years     1
# Name: Duration, dtype: int64
#
#
# Monthly    29
# Weekly      7
# Daily       4
# Name: Invest_Monitor, dtype: int64
#
#
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: Expect, dtype: int64
#
#
# Mutual Fund              18
# Equity                   10
# Fixed Deposits            9
# Public Provident Fund     3
# Name: Avenue, dtype: int64
#
#
# Retirement Plan    24
# Health Care        13
# Education           3
# Name: What are your savings objectives?, dtype: int64
#
#
# Capital Appreciation    30
# Dividend                 8
# Liquidity                2
# Name: Reason_Equity, dtype: int64
#
#
# Better Returns          24
# Fund Diversification    13
# Tax Benefits             3
# Name: Reason_Mutual, dtype: int64
#
#
# Assured Returns    26
# Safe Investment    13
# Tax Incentives      1
# Name: Reason_Bonds, dtype: int64
#
#
# Risk Free              19
# Fixed Returns          18
# High Interest Rates     3
# Name: Reason_FD, dtype: int64
#
#
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: Source, dtype: int64

# %% [markdown]
# ### Part 3. Bivariate Analysis

# %% [markdown]
# ##### 3.1
#
# - Compute the contingency table for Factor and Objective
# - Compute the contingency table for Reason_FD and Duration

# %%
pd.crosstab(data['Factor'], data['Objective'])
# Out:
# Objective       Capital Appreciation  Growth  Income
# Factor
# Locking Period                     1       0       0
# Returns                           19       3       3
# Risk                               6       8       0

# %%
pd.crosstab(data['Reason_FD'], data['Duration'])
# Out:
# Duration             1-3 years  3-5 years  Less than 1 year  More than 5 years
# Reason_FD
# Fixed Returns                7         11                 0                  0
# High Interest Rates          0          1                 1                  1
# Risk Free                   11          7                 1                  0

# %% [markdown]
# ##### 3.2 Bivariate numerical - categorical
# Conditional means for a numerical and categorical column are computed on a subset of the numerical column where the categorical column is set to one of its levels (i.e., distinct values).
#
# - Compute and print out conditional means for age and all categorical columns
# - Which age group has a preference for investing in stocks?

# %%
data.groupby('Stock_Market').mean()[['age']]
# Out:
#                     age
# Stock_Market
# No            23.800000
# Yes           28.371429

# %%
for column in data.describe(include='object').columns:  
    print(data.groupby(column).mean()[['age']], '\n', '\n')
# Out:
#               age
# gender
# Female  27.733333
# Male    27.840000
#
#
#                           age
# Investment_Avenues
# No                  23.000000
# Yes                 28.189189
#
#
#                     age
# Stock_Market
# No            23.800000
# Yes           28.371429
#
#
#                       age
# Factor
# Locking Period  23.000000
# Returns         27.960000
# Risk            27.857143
#
#
#                             age
# Objective
# Capital Appreciation  27.076923
# Growth                29.818182
# Income                26.666667
#
#
#                           age
# Purpose
# Returns             30.000000
# Savings for Future  28.666667
# Wealth Creation     27.500000
#
#
#                          age
# Duration
# 1-3 years          28.222222
# 3-5 years          28.157895
# Less than 1 year   23.000000
# More than 5 years  23.000000
#
#
#                       age
# Invest_Monitor
# Daily           25.000000
# Monthly         28.310345
# Weekly          27.285714
#
#
#                age
# Expect
# 10%-20%  27.666667
# 20%-30%  28.000000
# 30%-40%  26.600000
#
#
#                              age
# Avenue
# Equity                 27.900000
# Fixed Deposits         28.555556
# Mutual Fund            27.777778
# Public Provident Fund  25.333333
#
#
#                                          age
# What are your savings objectives?
# Education                          24.666667
# Health Care                        26.846154
# Retirement Plan                    28.708333
#
#
#                             age
# Reason_Equity
# Capital Appreciation  28.666667
# Dividend              25.375000
# Liquidity             24.500000
#
#
#                             age
# Reason_Mutual
# Better Returns        27.333333
# Fund Diversification  28.076923
# Tax Benefits          30.333333
#
#
#                        age
# Reason_Bonds
# Assured Returns  28.076923
# Safe Investment  27.692308
# Tax Incentives   22.000000
#
#
#                            age
# Reason_FD
# Fixed Returns        29.888889
# High Interest Rates  24.000000
# Risk Free            26.421053
#
#
#                                 age
# Source
# Financial Consultants     27.937500
# Internet                  22.750000
# Newspapers and Magazines  28.142857
# Television                30.000000

# %% [markdown]
# ##### 3.3 Correlation
# Compute correlation coefficients between age and other numerical columns. Which numerical columns have the strongest correlation with age? Name top 3.

# %%
data.corr()
# Answer: Debentures, PPF, Equity_Market
# Out:
#                        age  Mutual_Funds  Equity_Market  Debentures  \
# age               1.000000     -0.123914       0.246840    0.326638
# Mutual_Funds     -0.123914      1.000000       0.332043   -0.351495
# Equity_Market     0.246840      0.332043       1.000000   -0.016898
# Debentures        0.326638     -0.351495      -0.016898    1.000000
# Government_Bonds -0.093632     -0.114198      -0.237420    0.430323
# Fixed_Deposits   -0.033685     -0.031604      -0.238705   -0.470791
# PPF              -0.263167     -0.193665      -0.429003   -0.511169
# Gold             -0.057952     -0.401830      -0.050027   -0.137195
#
#                   Government_Bonds  Fixed_Deposits       PPF      Gold
# age                      -0.093632       -0.033685 -0.263167 -0.057952
# Mutual_Funds             -0.114198       -0.031604 -0.193665 -0.401830
# Equity_Market            -0.237420       -0.238705 -0.429003 -0.050027
# Debentures                0.430323       -0.470791 -0.511169 -0.137195
# Government_Bonds          1.000000       -0.531359 -0.240356 -0.300607
# Fixed_Deposits           -0.531359        1.000000  0.083633 -0.092730
# PPF                      -0.240356        0.083633  1.000000  0.125795
# Gold                     -0.300607       -0.092730  0.125795  1.000000
